# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Предобработка-и-исследовательский-анализ-данных" data-toc-modified-id="Предобработка-и-исследовательский-анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка и исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Датасет-contract" data-toc-modified-id="Датасет-contract-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Датасет <code>contract</code></a></span></li><li><span><a href="#Датасет-personal" data-toc-modified-id="Датасет-personal-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Датасет <code>personal</code></a></span></li><li><span><a href="#Датасет-internet" data-toc-modified-id="Датасет-internet-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Датасет <code>internet</code></a></span></li><li><span><a href="#Датасет-phone" data-toc-modified-id="Датасет-phone-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Датасет <code>phone</code></a></span></li></ul></li><li><span><a href="#Объединение-таблиц-по-ID-клиента,-feature-ingeneering,-анализ-признаков" data-toc-modified-id="Объединение-таблиц-по-ID-клиента,-feature-ingeneering,-анализ-признаков-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Объединение таблиц по ID клиента, feature ingeneering, анализ признаков</a></span><ul class="toc-item"><li><span><a href="#Объединение-таблиц" data-toc-modified-id="Объединение-таблиц-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Объединение таблиц</a></span></li><li><span><a href="#Выделение-целевого-признака" data-toc-modified-id="Выделение-целевого-признака-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Выделение целевого признака</a></span></li><li><span><a href="#Создание-новых-признаков" data-toc-modified-id="Создание-новых-признаков-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Создание новых признаков</a></span></li><li><span><a href="#Исследовательский-анализ-данных-объединённой-таблицы" data-toc-modified-id="Исследовательский-анализ-данных-объединённой-таблицы-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Исследовательский анализ данных объединённой таблицы</a></span></li><li><span><a href="#Корреляционный-анализ-признаков" data-toc-modified-id="Корреляционный-анализ-признаков-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Корреляционный анализ признаков</a></span></li></ul></li><li><span><a href="#Подготовка-данных-для-обучения" data-toc-modified-id="Подготовка-данных-для-обучения-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Подготовка данных для обучения</a></span></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><span><a href="#Модель-DecisionTree" data-toc-modified-id="Модель-DecisionTree-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Модель DecisionTree</a></span></li><li><span><a href="#Модель-LightGBM" data-toc-modified-id="Модель-LightGBM-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Модель LightGBM</a></span></li><li><span><a href="#Модель-CatBoost" data-toc-modified-id="Модель-CatBoost-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Модель CatBoost</a></span></li><li><span><a href="#Модель-нейронная-сеть" data-toc-modified-id="Модель-нейронная-сеть-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Модель нейронная сеть</a></span></li><li><span><a href="#Сводная-таблица" data-toc-modified-id="Сводная-таблица-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Сводная таблица</a></span></li></ul></li><li><span><a href="#Тестирование-лучшей-модели" data-toc-modified-id="Тестирование-лучшей-модели-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Тестирование лучшей модели</a></span><ul class="toc-item"><li><span><a href="#Проверка-качества-лучшей-модели" data-toc-modified-id="Проверка-качества-лучшей-модели-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Проверка качества лучшей модели</a></span></li><li><span><a href="#Расчёт-Accuracy,-построение-матрицы-ошибок-и-графика-Precision-Recall" data-toc-modified-id="Расчёт-Accuracy,-построение-матрицы-ошибок-и-графика-Precision-Recall-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Расчёт Accuracy, построение матрицы ошибок и графика Precision-Recall</a></span></li><li><span><a href="#Анализ-важности-признаков" data-toc-modified-id="Анализ-важности-признаков-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Анализ важности признаков</a></span></li><li><span><a href="#Дополнительное-исследование-для-одного-из-признаков" data-toc-modified-id="Дополнительное-исследование-для-одного-из-признаков-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Дополнительное исследование для одного из признаков</a></span></li></ul></li><li><span><a href="#Итоговый-вывод" data-toc-modified-id="Итоговый-вывод-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Итоговый вывод</a></span></li></ul></div>

# %% [markdown]
# # Проект: предсказание оттока клиентов

# %% [markdown]
# Описание проекта: оператор связи «ТелеДом» хочет бороться с оттоком клиентов. Для этого его сотрудники начнут предлагать промокоды и специальные условия всем, кто планирует отказаться от услуг связи. Чтобы заранее находить таких пользователей, «ТелеДому» нужна модель, которая будет предсказывать, разорвёт ли абонент договор. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и услугах. Наша задача — обучить на этих данных модель для прогноза оттока клиентов. **Показателем качества лучшей модели на тестовой выборке будет считаться значение метрики ROC-AUC не менее 0.85**

# %% [markdown]
# Описание данных: база данных представлена одним файлом, она состоит из нескольких таблиц.
#
# - `contract` — информация о договорах (*):
#
#   - customerID — ID абонента
#   - BeginDate — дата начала действия договора
#   - EndDate — дата окончания действия договора
#   - Type — тип оплаты: раз в год-два или ежемесячно
#   - PaperlessBilling — электронный расчётный лист
#   - PaymentMethod — тип платежа
#   - MonthlyCharges — расходы за месяц
#   - TotalCharges — общие расходы абонента
#
# - `personal` — персональные данные клиентов
#
#   - customerID — ID пользователя
#   - gender — пол
#   - SeniorCitizen — является ли абонент пенсионером
#   - Partner — есть ли у абонента супруг или супруга
#   - Dependents — есть ли у абонента дети
#
# - `internet` — информация об интернет-услугах
#
#   - customerID — ID пользователя
#   - InternetService — тип подключения
#   - OnlineSecurity — блокировка опасных сайтов
#   - OnlineBackup — облачное хранилище файлов для резервного копирования данных
#   - DeviceProtection — антивирус
#   - TechSupport — выделенная линия технической поддержки
#   - StreamingTV — стриминговое телевидение
#   - StreamingMovies — каталог фильмов
#
# - `phone` — информация об услугах телефонии
#
#   - customerID — ID пользователя
#   - MultipleLines — подключение телефона к нескольким линиям одновременно.
#
# (*) Информация о договорах актуальна на 1 февраля 2020.

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# Загрузим библиотеки

# %%
# !pip install -q catboost

# %%
# !pip install -q lightgbm

# %%
# !pip install -q phik

# %%
# !pip install -q shap

# %%
# !pip install -q scikeras
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-cpu 2.7.0 requires keras<2.8,>=2.7.0rc0, but you have keras 3.9.2 which is incompatible.

# %%
# !pip install -U scikit-learn

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
import torch
import torch.nn as nn
import urllib
import sqlite3
import shap
import warnings
warnings.filterwarnings('ignore')
import sklearn

import phik
from phik import report
from phik.report import plot_correlation_matrix

from sklearn.dummy import DummyClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, KFold
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, \
                            recall_score, precision_recall_curve, \
                            confusion_matrix, average_precision_score, \
                            ConfusionMatrixDisplay

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

from lightgbm import LGBMClassifier

from catboost import CatBoostClassifier

from os.path import exists

# %%
# создадим константы
TEST_SIZE = 0.25
RANDOM_STATE = 120525 # дата начала работы над проектом

# %% [markdown]
# Подключимся к базе данных

# %%
if not exists('ds-plus-final.db'):
    url = 'https://code.s3.yandex.net/data-scientist/ds-plus-final.db'
    urllib.request.urlretrieve(url, 'ds-plus-final.db')

# %%
connection = sqlite3.connect('ds-plus-final.db')

# %% [markdown]
# Создадим датасеты с соответствующими таблицам названиями и убедимся, что данные загружаются

# %%
contract = pd.read_sql('SELECT * FROM contract', connection)
contract.head()
# Out:
#    customerID   BeginDate EndDate            Type PaperlessBilling  \
# 0  7590-VHVEG  2020-01-01      No  Month-to-month              Yes
# 1  5575-GNVDE  2017-04-01      No        One year               No
# 2  3668-QPYBK  2019-10-01      No  Month-to-month              Yes
# 3  7795-CFOCW  2016-05-01      No        One year               No
# 4  9237-HQITU  2019-09-01      No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges TotalCharges
# 0           Electronic check          29.85        31.04
# 1               Mailed check          56.95      2071.84
# 2               Mailed check          53.85       226.17
# 3  Bank transfer (automatic)           42.3       1960.6
# 4           Electronic check           70.7        353.5

# %%
personal = pd.read_sql('SELECT * FROM personal', connection)
personal.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female             0     Yes         No
# 1  5575-GNVDE    Male             0      No         No
# 2  3668-QPYBK    Male             0      No         No
# 3  7795-CFOCW    Male             0      No         No
# 4  9237-HQITU  Female             0      No         No

# %%
internet = pd.read_sql('SELECT * FROM internet', connection)
internet.head()
# Out:
#    customerID InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0  7590-VHVEG             DSL             No          Yes               No
# 1  5575-GNVDE             DSL            Yes           No              Yes
# 2  3668-QPYBK             DSL            Yes          Yes               No
# 3  7795-CFOCW             DSL            Yes           No              Yes
# 4  9237-HQITU     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies
# 0          No          No              No
# 1          No          No              No
# 2          No          No              No
# 3         Yes          No              No
# 4          No          No              No

# %%
phone = pd.read_sql('SELECT * FROM phone', connection)
phone.head()
# Out:
#    CustomerId MultipleLines
# 0  5575-GNVDE            No
# 1  3668-QPYBK            No
# 2  9237-HQITU            No
# 3  9305-CDSKC           Yes
# 4  1452-KIOVK           Yes

# %% [markdown]
# Выводы по разделу:
#
# - загрузили необходимые библиотеки и создали константы;
# - подключились к базе данных, сохранили в переменные соответствующие таблицы;
# - данные загружены успешно, готовы к предобработке и исследовательскому анализу.

# %% [markdown]
# ## Предобработка и исследовательский анализ данных

# %% [markdown]
# Создадим ряд функций, которые помогут нам детальнее взглянуть на предоставленные данные

# %%
# функция для получения информации о датасете, о наличии пропущенных значений
# и явных дубликатов

def get_info(dataset):
    print('Случайные пять строк датасета:')
    display(dataset.sample(5))
    print('Общая информация:')
    dataset.info()
    print('Описание:')
    dataset.describe()
    print('Количество пропущенных значений:')
    display(dataset.isna().sum())
    print('Количество явных дубликатов:')
    display(dataset.duplicated().sum())

# функция для вычисления доли выбросов в количественных признаках
def outliers(dataset, column):
    q1 = dataset[column].quantile(0.25)
    q3 = dataset[column].quantile(0.75)
    iqr = q3 - q1
    quant1 = q1 - 1.5*iqr
    quant3 = q3 + 1.5*iqr
    total = dataset.shape[0]
    emission = dataset[(dataset[column] < quant1) | \
     (dataset[column] > quant3)].shape[0]
    emission_quant = (emission / total) * 100
    return np.round((emission_quant), decimals=2)

# функция для построения гистограммы распределения количественных признаков
def histogram(dataset, column):
    dataset[column].plot(kind='hist', bins=20, grid=True, \
                figsize=(5, 5), title=(f'Распределение признака "{column}"'))
    plt.xlabel(column)
    plt.ylabel('Количество')
    plt.show()
    return None

# функция для построения диаграммы размаха
def whiskers(dataset, column):
    dataset.boxplot(column, figsize=(5, 5))
    plt.title(f'Диаграмма размаха признака "{column}"')
    plt.ylabel('Количество')
    plt.show()
    print(dataset[column].describe().round(2))
    return None

# функция для построения диаграммы распределения категориальных признаков
def categorial(dataset, column):
    dataset[column].value_counts().plot(
    kind = 'pie',
    ylabel = '',
    autopct = '%1.1f%%',
    figsize = (5,5),
    title = f'Процентное распределение признака "{column}"')
    plt.show()
    return None

# %% [markdown]
# ### Датасет `contract`

# %%
get_info(contract)
# Out:
# Случайные пять строк датасета:
#       customerID   BeginDate EndDate            Type PaperlessBilling  \
# 216   9286-BHDQG  2014-02-01      No        Two year               No
# 6056  8331-ZXFOE  2015-04-01      No        One year              Yes
# 1195  4468-KAZHE  2018-06-01      No  Month-to-month              Yes
# 720   4697-LUPSU  2019-12-01      No        One year               No
# 5529  5919-VCZYM  2019-12-01      No  Month-to-month               No
#
#                 PaymentMethod MonthlyCharges TotalCharges
# 216   Credit card (automatic)          45.25      3355.74
# 6056  Credit card (automatic)           71.1      4165.04
# 1195         Electronic check           60.0       1200.0
# 720              Mailed check           20.2        42.82
# 5529             Mailed check          20.05         40.1
# Общая информация:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
# ...

# %% [markdown]
# Приведём названия столбцов к snake_case-виду

# %%
contract.rename(columns={'customerID': 'customer_id', \
                'BeginDate': 'begin_date', 'EndDate': 'end_date',
                'Type': 'type', 'PaperlessBilling': 'paperless_billing', \
                'PaymentMethod': 'payment_method', \
                'MonthlyCharges': 'monthly_charges', \
                'TotalCharges': 'total_charges'}, inplace=True)

# %% [markdown]
# Исправим типы данных

# %%
contract['begin_date'] = pd.to_datetime(contract['begin_date'])
contract['total_charges'] = pd.to_numeric(contract['total_charges'], \
                                          errors='coerce')
contract['monthly_charges'] = pd.to_numeric(contract['monthly_charges'], \
                                            errors='coerce')

# %%
contract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        7043 non-null   object
#  1   begin_date         7043 non-null   datetime64[ns]
#  2   end_date           7043 non-null   object
#  3   type               7043 non-null   object
#  4   paperless_billing  7043 non-null   object
#  5   payment_method     7043 non-null   object
#  6   monthly_charges    7043 non-null   float64
#  7   total_charges      7032 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 440.3+ KB

# %%
contract['customer_id'].nunique()
# Out:
# 7043

# %% [markdown]
# В начальном описании таблиц название признака customer_id отличается только для таблицы `customer` ("абонент" против "пользователь"). Все ID для этой таблицы уникальны, а значит, если количество значений совпадёт, будем объединять таблицы в дальнейшем по данному признаку

# %%
dataset = contract
column_list = ['monthly_charges', 'total_charges']
for column in column_list:
    print(f'Доля выбросов в {column}, в процентах: {outliers(dataset, column)}')
# Out:
# Доля выбросов в monthly_charges, в процентах: 0.0
# Доля выбросов в total_charges, в процентах: 2.77

# %% [markdown]
# Количество выбросов незначительное, можно не удалять

# %%
begin_date_year = contract['begin_date'].dt.year
year_count = begin_date_year.value_counts().sort_index()

# %%
plt.figure(figsize=(5, 5))
year_count.plot(kind='bar', \
              title='Количество контрактов по годам начала действия договора')
plt.xlabel('Год начала действия договора')
plt.xticks(rotation = 45)
plt.ylabel('Количество контрактов')
plt.show()

# %% [markdown]
# Пик по количеству заключенных контрактов приходится на 2019 год. В 2013 году сервис, видимо, только стартовал

# %%
contract['end_date'].value_counts().sort_index()
# Out:
# 2014-06-01       1
# 2014-09-01       2
# 2014-10-01       1
# 2014-11-01       1
# 2014-12-01       2
#               ...
# 2019-10-01      31
# 2019-11-01      30
# 2019-12-01      38
# 2020-01-01      39
# No            5942
# Name: end_date, Length: 67, dtype: int64

# %% [markdown]
# 5942 действующих контракта (с неоконченной датой) из 7043 на момент выгрузки данных, не выглядит критично

# %%
contract['type'].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
contract['type'].value_counts()
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: type, dtype: int64

# %% [markdown]
# Компания предлагает три типа контрактов, при этом подписок с ежемесячной оплатой больше, чем суммарно с годовой-двухгодовой. С одной стороны, это приносит больше дивидентов (на помесячные подписки обычно не действуют скидочные программы), с другой - такие клиенты более склонны отказаться от продления.

# %%
contract['paperless_billing'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# Бинарный признак, кодирование проведём позже

# %%
contract['payment_method'].unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
contract['payment_method'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: payment_method, dtype: int64

# %% [markdown]
# Четыре варианта оплаты, самым популярным из них явлется оплата по электронному счёту

# %%
histogram(contract, 'monthly_charges')
whiskers(contract, 'monthly_charges')
# Out:
# count    7043.00
# mean       64.76
# std        30.09
# min        18.25
# 25%        35.50
# 50%        70.35
# 75%        89.85
# max       118.75
# Name: monthly_charges, dtype: float64

# %% [markdown]
# Выбросы отсутствуют, в целом значения адекватные. Распределение нормальное, есть два пика - на 20 и 80 у.е.

# %%
histogram(contract, 'total_charges')
whiskers(contract, 'total_charges')
# Out:
# count    7032.00
# mean     2118.62
# std      2112.74
# min        19.05
# 25%       439.74
# 50%      1345.28
# 75%      3239.32
# max      9221.38
# Name: total_charges, dtype: float64

# %% [markdown]
# Аналогично, общие расходы абонентов не выглядят подозрительными. Выбросы таковыми считать не будем, даже максимальное значение в 9221 у.е. можно допустить. Проверим датасет ещё раз

# %%
contract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        7043 non-null   object
#  1   begin_date         7043 non-null   datetime64[ns]
#  2   end_date           7043 non-null   object
#  3   type               7043 non-null   object
#  4   paperless_billing  7043 non-null   object
#  5   payment_method     7043 non-null   object
#  6   monthly_charges    7043 non-null   float64
#  7   total_charges      7032 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 440.3+ KB

# %% [markdown]
# Типы данных соответствуют значениям, переходим к следующему датасету

# %% [markdown]
# ### Датасет `personal`

# %%
get_info(personal)
# Out:
# Случайные пять строк датасета:
#       customerID  gender SeniorCitizen Partner Dependents
# 1690  5740-YHGTW    Male             0     Yes        Yes
# 3719  6823-SIDFQ    Male             0      No         No
# 2396  4083-BFNYK  Female             1     Yes         No
# 4562  5322-TEUJK  Female             0     Yes        Yes
# 3627  3243-ZHOHY  Female             0      No         No
# Общая информация:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   object
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: object(5)
# memory usage: 275.2+ KB
# Описание:
# Количество пропущенных значений:
# customerID       0
# gender           0
# SeniorCitizen    0
# ...

# %% [markdown]
# Те же 7043 записи. Пропущенных значений и явных дубликатов нет. Приведём названия столбцов к snake_case

# %%
personal.rename(columns={'customerID': 'customer_id', \
                'SeniorCitizen': 'senior_citizen', 'Partner': 'partner', \
                'Dependents': 'dependents'}, inplace=True)

# %%
personal['customer_id'].nunique()
# Out:
# 7043

# %% [markdown]
# Все значения ID уникальны

# %%
personal['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %% [markdown]
# Скорее всего, оператор связи "ТелеДом" - российская компания, хотя цифры в признаке `monthly_charges` на это не намекали. Не вдаваясь в полемику, посмотрим на распределение признака `gender` в процентном соотношении

# %%
categorial(personal, 'gender')

# %% [markdown]
# Почти идеальное распределение долей мужчин и женщин, 50 на 50

# %%
personal['senior_citizen'].unique()
# Out:
# array(['0', '1'], dtype=object)

# %%
categorial(personal, 'senior_citizen')

# %% [markdown]
# Признак уже приведён к численному виду. Логично предположить, что абонентов-пенсионеров - меньшее количество (цифра 1, 16.2%). Клиентов допенсионного возраста - большинство (цифра 0, 83.8%)

# %%
personal['partner'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
categorial(personal, 'partner')

# %% [markdown]
# Бинарный признак. Распределение почти одинаковое, с небольшим преобладанием клиентов не в браке

# %%
personal['dependents'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
categorial(personal, 'dependents')

# %% [markdown]
# Клиентов с детьми примерно 1/3 от общего количества

# %% [markdown]
# ### Датасет `internet`

# %%
get_info(internet)
# Out:
# Случайные пять строк датасета:
#       customerID InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 211   7605-BDWDC             DSL            Yes          Yes               No
# 3967  7136-IHZJA             DSL            Yes          Yes               No
# 2591  3866-MDTUB             DSL            Yes           No               No
# 3893  0909-SDHNU             DSL            Yes           No               No
# 2616  9124-LHCJQ     Fiber optic             No           No               No
#
#      TechSupport StreamingTV StreamingMovies
# 211          Yes          No             Yes
# 3967         Yes          No             Yes
# 2591          No         Yes             Yes
# 3893          No          No              No
# 2616          No          No             Yes
# Общая информация:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5517 entries, 0 to 5516
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ...

# %% [markdown]
# Количество записей ожидаемо меньше, 5517. Пропусков и явных дубликатов снова нет, приведём названия столбцов к snake_case

# %%
internet.rename(columns={'customerID': 'customer_id', \
  'InternetService': 'internet_service', 'OnlineSecurity': 'online_security', \
  'OnlineBackup': 'online_backup', 'DeviceProtection': 'device_protection', \
  'TechSupport': 'tech_support', 'StreamingTV': 'streaming_tv', \
  'StreamingMovies': 'streaming_movies'}, inplace=True)

# %%
internet['customer_id'].nunique()
# Out:
# 5517

# %% [markdown]
# Все ID уникальные

# %%
columns = ['internet_service', 'online_security', 'online_backup', 'device_protection', \
           'tech_support', 'streaming_tv', 'streaming_movies']
for column in columns:
    categorial(internet, column)

# %% [markdown]
# Оптоволокно выигрывает у устаревших телефонных линий примерно на 12%, по остальным сервисам видно, что они скорее не подключены. Все признаки - бинарные

# %% [markdown]
# ### Датасет `phone`

# %%
get_info(phone)
# Out:
# Случайные пять строк датасета:
#       CustomerId MultipleLines
# 1897  3177-LASXD            No
# 2978  6504-VBLFL            No
# 571   1775-KWJKQ           Yes
# 3521  3129-AAQOU           Yes
# 5470  9090-SGQXL           Yes
# Общая информация:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustomerId     6361 non-null   object
#  1   MultipleLines  6361 non-null   object
# dtypes: object(2)
# memory usage: 99.5+ KB
# Описание:
# Количество пропущенных значений:
# CustomerId       0
# MultipleLines    0
# dtype: int64
# Количество явных дубликатов:
# 0

# %% [markdown]
# Все предоставленные датасеты очищены от пропусков и дубликатов, это радует

# %%
phone.rename(columns={'CustomerId': 'customer_id', \
              'MultipleLines': 'multiple_lines'}, inplace=True)

# %%
phone['customer_id'].nunique()
# Out:
# 6361

# %%
phone['multiple_lines'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
categorial(phone, 'multiple_lines')

# %% [markdown]
# Чуть чаще клиенты не подключают телефон к нескольким линиям одновременно, 53.3% против 46.7%. Признак бинарный

# %% [markdown]
# Выводы по разделу:
#
# - привели названия всех столбцов в датасетах к единому, snake_case-виду;
# - данные не содержат выбросов, пропусков и явных дубликатов;
# - исправили типы данных в соответствии с их значениями;
# - подписок с ежемесячной оплатой больше, чем суммарно с годовой-двухгодовой. С одной стороны, это приносит больше дивидентов (на помесячные подписки обычно не действуют скидочные программы), с другой - такие клиенты более склонны отказаться от продления;
# - большая часть клиентов - допенсионного возраста, без детей. Распределения по полу (мужчина/женщина) и семейному статусу (не в браке/в браке) - примерно одинаковые.

# %% [markdown]
# ## Объединение таблиц по ID клиента, feature ingeneering, анализ признаков

# %% [markdown]
# ### Объединение таблиц

# %% [markdown]
# Таблицы имеют разное количество записей и, как следствие, разное значение `customer_id`. Объединим их так, чтобы ничего не потерялось

# %%
data = pd.merge(contract, personal, on='customer_id', how='outer')
data = pd.merge(data, internet, on='customer_id', how='outer')
data = pd.merge(data, phone, on='customer_id', how='outer')

# %%
data.shape
# Out:
# (7043, 20)

# %%
data.sample(5)
# Out:
#      customer_id begin_date end_date            type paperless_billing  \
# 6146  4009-ALQFH 2017-10-01       No  Month-to-month               Yes
# 3812  8573-JGCZW 2018-09-01       No        One year               Yes
# 3153  9099-FTUHS 2018-03-01       No  Month-to-month                No
# 4041  5862-BRIXZ 2016-04-01       No        Two year               Yes
# 2781  5533-NHFRF 2019-07-01       No  Month-to-month               Yes
#
#                  payment_method  monthly_charges  total_charges  gender  \
# 6146           Electronic check            99.50        2841.72  Female
# 3812  Bank transfer (automatic)            19.65         347.41    Male
# 3153           Electronic check            54.40        1251.20  Female
# 4041  Bank transfer (automatic)            60.75        2794.50    Male
# 2781           Electronic check            44.40         310.80    Male
#
#      senior_citizen partner dependents internet_service online_security  \
# ...

# %% [markdown]
# Все строки и столбцы на месте

# %%
get_info(data)
# Out:
# Случайные пять строк датасета:
#      customer_id begin_date    end_date            type paperless_billing  \
# 2369  9570-KYEUA 2014-10-01          No        Two year                No
# 3874  4570-QHXHL 2019-05-01          No  Month-to-month               Yes
# 1631  4248-QPAVC 2018-06-01          No  Month-to-month               Yes
# 4661  9415-ZNBSX 2014-04-01  2017-10-01        Two year               Yes
# 6216  7162-WPHPM 2015-04-01          No        Two year                No
#
#                  payment_method  monthly_charges  total_charges  gender  \
# 2369    Credit card (automatic)            99.25        6352.00    Male
# 3874           Electronic check            43.75         417.38  Female
# 1631  Bank transfer (automatic)            85.35        1860.63  Female
# 4661  Bank transfer (automatic)            89.00        4037.04  Female
# 6216    Credit card (automatic)            71.60        4152.80    Male
#
# ...

# %% [markdown]
# Типы данных не изменились, а пропущенные значения появились. Это ожидаемо, т.к. таблицы `internet` и `phone` не содержат информацию о части клиентов. Интерес составляют 11 пропусков в признаке `total_charges`, посмотрим детальнее

# %%
num_empty = data[data['total_charges'].isna()]
num_empty
# Out:
#      customer_id begin_date end_date      type paperless_billing  \
# 488   4472-LVYGI 2020-02-01       No  Two year               Yes
# 753   3115-CZMZD 2020-02-01       No  Two year                No
# 936   5709-LVOEQ 2020-02-01       No  Two year                No
# 1082  4367-NUYAO 2020-02-01       No  Two year                No
# 1340  1371-DWPAZ 2020-02-01       No  Two year                No
# 3331  7644-OMVMY 2020-02-01       No  Two year                No
# 3826  3213-VVOLG 2020-02-01       No  Two year                No
# 4380  2520-SGTTA 2020-02-01       No  Two year                No
# 5218  2923-ARZLG 2020-02-01       No  One year               Yes
# 6670  4075-WKNIU 2020-02-01       No  Two year                No
# 6754  2775-SEFEE 2020-02-01       No  Two year               Yes
#
#                  payment_method  monthly_charges  total_charges  gender  \
# 488   Bank transfer (automatic)            52.55            NaN  Female
# ...

# %% [markdown]
# Все 11 строк - с началом действия договора, совпадающим с датой выгрузки датасета (1 февраля 2020 года). Заполним пропущенные значения нулями, т.к. клиенты ещё не успели накопить платежи

# %%
data['total_charges'] = data['total_charges'].fillna(0)

# %%
get_info(data)
# Out:
# Случайные пять строк датасета:
#      customer_id begin_date    end_date            type paperless_billing  \
# 3490  7743-EXURX 2019-03-01          No  Month-to-month               Yes
# 67    3410-YOQBQ 2017-07-01          No        Two year                No
# 4202  3146-JTQHR 2019-04-01          No        One year                No
# 3602  3038-PQIUY 2016-12-01  2020-01-01  Month-to-month               Yes
# 6999  2108-XWMPY 2019-07-01          No  Month-to-month               Yes
#
#                  payment_method  monthly_charges  total_charges  gender  \
# 3490           Electronic check            51.05         589.63    Male
# 67                 Mailed check            79.20        2455.20  Female
# 4202  Bank transfer (automatic)            19.60         201.88    Male
# 3602  Bank transfer (automatic)            66.15        2447.55  Female
# 6999               Mailed check            35.45         248.15    Male
#
# ...

# %% [markdown]
# ### Выделение целевого признака

# %% [markdown]
# Выделим в целевую переменную (`target`) признак `end_date`. Нам важнее распознать уходящего клиента, чем оставшегося

# %%
data['target'] = (data['end_date'] != 'No').astype('int')

# %% [markdown]
# Заменим значение "No" в столбце `end_date` на дату выгрузки датасета, 1 февраля 2020 года

# %%
data['end_date'] = data['end_date'].replace('No', '2020-02-01')

# %%
# приведём к формату даты
data['end_date'] = pd.to_datetime(data['end_date'])

# %%
categorial(data, 'target')

# %% [markdown]
# Наблюдаем большой дисбаланс классов

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        7043 non-null   object
#  1   begin_date         7043 non-null   datetime64[ns]
#  2   end_date           7043 non-null   datetime64[ns]
#  3   type               7043 non-null   object
#  4   paperless_billing  7043 non-null   object
#  5   payment_method     7043 non-null   object
#  6   monthly_charges    7043 non-null   float64
#  7   total_charges      7043 non-null   float64
#  8   gender             7043 non-null   object
#  9   senior_citizen     7043 non-null   object
#  10  partner            7043 non-null   object
#  11  dependents         7043 non-null   object
#  12  internet_service   5517 non-null   object
#  13  online_security    5517 non-null   object
#  14  online_backup      5517 non-null   object
# ...

# %% [markdown]
# ### Создание новых признаков

# %% [markdown]
# Добавим в датасет новые признаки

# %%
# period (общая длительность пользования клиентами сервисом, в днях)
data['period'] = (data['end_date'] - data['begin_date']).dt.days

# %%
# money_per_day (прибыль от каждого клиента в день)
data['money_per_day'] = round((data['total_charges'] / data['period']), 2)

# %% [markdown]
# Признак `customer_id` после объединения датасетов нам больше не нужен, удалим его

# %%
data = data.drop(columns='customer_id')
assert 'customer_id' not in data.columns

# %% [markdown]
# Проверим, что столбцы добавились корректно

# %%
data.sample(15)
# Out:
#      begin_date   end_date            type paperless_billing  \
# 6444 2017-03-01 2020-02-01        One year               Yes
# 4268 2017-03-01 2020-01-01        One year               Yes
# 170  2016-07-01 2019-05-01        One year               Yes
# 2783 2016-07-01 2020-02-01  Month-to-month               Yes
# 459  2020-01-01 2020-02-01  Month-to-month               Yes
# 1818 2015-02-01 2020-02-01  Month-to-month                No
# 937  2019-04-01 2019-11-01  Month-to-month               Yes
# 621  2014-12-01 2020-02-01        One year               Yes
# 1280 2014-02-01 2020-02-01        Two year               Yes
# 5770 2017-01-01 2019-03-01        One year                No
# 50   2016-07-01 2020-02-01  Month-to-month               Yes
# 6100 2017-07-01 2020-02-01  Month-to-month               Yes
# 6987 2017-03-01 2020-02-01        One year               Yes
# 3499 2019-11-01 2020-02-01  Month-to-month                No
# ...

# %% [markdown]
# ### Исследовательский анализ данных объединённой таблицы

# %%
# разделим клиентов по целевому признаку
leave = data[data['target'] == 1]
not_leave = data[data['target'] != 1]

cat_features = ['internet_service', 'type', 'payment_method', \
                'paperless_billing', 'gender', 'senior_citizen', 'partner', \
                'dependents', 'online_security', 'online_backup', \
                'device_protection', 'tech_support', 'streaming_tv', \
                'streaming_movies', 'multiple_lines']
num_features = ['monthly_charges', 'total_charges', 'money_per_day', 'period']

# функция для построения графиков распределения
def plot_distribution(features):
    for feature in features:
        comparison_df = pd.DataFrame({
            'ушёл': leave[feature].value_counts(),
            'остался': not_leave[feature].value_counts()
        }).fillna(0)

        comparison_df.plot(kind='bar', figsize=(5, 5), width=0.8, \
                           color=['red', 'green'])
        plt.title(f'Распределение для {feature}')
        plt.xlabel('Значение признака')
        plt.ylabel('Количество')
        plt.legend(title='Клиент:')
        plt.xticks(rotation=45, ha='right')
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        plt.show()

# построение графиков для категориальных признаков
plot_distribution(cat_features)

# %% [markdown]
# На графиках видно, что более склонны покинуть сервис клиенты допенсионного возраста, без детей, состоящие в браке. Используют оптоволоконную линию связи, контракт - с помесячной оплатой, счёт выставляется в электронном виде. Есть небольшой набор подключенных интернет-услуг и телефонии

# %% [markdown]
# Визуализируем плотности и взаимосвязи между непрерывными признаками и оттоком клиентов

# %%
def plot_numeric_distributions(features):
    for feature in features:
        plt.figure(figsize=(10, 5))

        # плотность распределений для ушедших и оставшихся клиентов
        sns.histplot(data=leave, x=feature, stat='density', kde=True, \
                     color='red', alpha=0.6, label='клиент ушёл')
        sns.histplot(data=not_leave, x=feature, stat='density', kde=True, \
                     color='green', alpha=0.6, label='клиент остался')

        # средние значения для ушедших и оставшихся клиентов
        mean_leave = leave[feature].mean()
        mean_not_leave = not_leave[feature].mean()

        plt.axvline(mean_leave, color='red', linestyle='--', \
                    label=f'среднее значение ушедшего ({mean_leave:.2f})')
        plt.axvline(mean_not_leave, color='green', linestyle='--', \
                  label=f'среднее значение оставшегося ({mean_not_leave:.2f})')

        plt.title(f'Распределение для {feature}')
        plt.xlabel(f'{feature}')
        plt.ylabel('Плотность')
        plt.legend()
        plt.grid(axis='y', linestyle='--', alpha=0.7)

        plt.xticks(ha='right')
        plt.show()

# %%
plot_numeric_distributions(num_features)

# %% [markdown]
# Клиент больше платит в месяц и в сутки - больше шансов, что покинет сервис, тут всё логично. Ушедшие клиенты суммарно потратили до 5000 у.е., скорее всего это те, кто оплачивал сервис помесячно. Высок риск потери клиентов, пользующихся сервисом на протяжении трёх-четырёх лет

# %% [markdown]
# Покажем долю оттока клиентов внутри каждой категории. Это должно помочь понять, какие категории больше коррелируют с уходом клиентов

# %%
def plot_categorical_target_relation(features):
    for feature in features:
        plt.figure(figsize=(5, 5))

        # рассчитаем долю оттока для каждой категории
        churn_rate = data.groupby(feature)['target'].mean()

        sns.barplot(x=churn_rate.index, y=churn_rate.values, palette='coolwarm')

        # добавим среднюю линию оттока (общая)
        plt.axhline(data['target'].mean(), color='blue', linestyle='--', \
                    label=f'средний отток ({data["target"].mean():.2f})')

        plt.title(f'Средний отток для {feature}')
        plt.xlabel(f'{feature}')
        plt.ylabel('Средний уровень оттока')
        plt.legend()

        plt.xticks(rotation=45, ha='right')
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        plt.show()

# %%
plot_categorical_target_relation(cat_features)

# %% [markdown]
# Здесь в целом ничего нового относительно предыдущих выводов

# %% [markdown]
# Построим портрет типичного клиента, который покидает сервис

# %%
profile_table = pd.DataFrame()

# метрики для числовых признаков
profile_table['Среднее, ушёл'] = \
                    round((data[data['target'] == 1][num_features].mean()), 2)
profile_table['Среднее, остался'] = \
                    round((data[data['target'] == 0][num_features].mean()), 2)
profile_table['Разница (%)'] = round((((profile_table['Среднее, ушёл'] - \
                                 profile_table['Среднее, остался']) /
                                profile_table['Среднее, остался'] * 100)), 2)

# мода для категориальных признаков
for feature in cat_features:
    left_mode = data[data['target'] == 1][feature].mode()[0]
    stayed_mode = data[data['target'] == 0][feature].mode()[0]

    profile_table.loc[feature, 'Мода, ушёл'] = left_mode
    profile_table.loc[feature, 'Мода, остался'] = stayed_mode

print(profile_table)
# Out:
#                    Среднее, ушёл  Среднее, остался  Разница (%)  \
# monthly_charges            75.55             62.76        20.38
# total_charges            2371.38           2067.87        14.68
# money_per_day               2.55              2.11        20.85
# period                    924.86            893.68         3.49
# internet_service             NaN               NaN          NaN
# type                         NaN               NaN          NaN
# payment_method               NaN               NaN          NaN
# paperless_billing            NaN               NaN          NaN
# gender                       NaN               NaN          NaN
# senior_citizen               NaN               NaN          NaN
# partner                      NaN               NaN          NaN
# dependents                   NaN               NaN          NaN
# online_security              NaN               NaN          NaN
# online_backup                NaN               NaN          NaN
# ...

# %% [markdown]
# Портрет ушедшего клиента получается следующий: высокая помесячная и суммарная оплата, 3 года пользования сервисом, в браке, есть подключенные интернет-сервисы и телефония

# %% [markdown]
# ### Корреляционный анализ признаков

# %%
# настроим interval_cols для корректной оценки корреляции
# для переменных разного типа
interval_cols = ['monthly_charges', 'total_charges', 'period', 'money_per_day']

corr_matrix = data.phik_matrix(interval_cols = interval_cols)

# %%
# построим тепловую карту коэффициентов корреляции phik
plot_correlation_matrix(corr_matrix.values,
                       x_labels = corr_matrix.columns,
                       y_labels = corr_matrix.index,
                       vmin = 0,
                       vmax = 1,
                       color_map= "Greens",
                       title = 'Тепловая карта коэффициентов корреляции phik',
                       fontsize_factor = 1.5,
                       figsize = (20, 12))
plt.show()

# %% [markdown]
# Используя шкалу Чеддока, сопоставим тесноту связей между входными признаками и целевым `target` (0,1-0,3 - слабая; 0,3-0,5 - умеренная; 0,5-0,7 - заметная; 0,7-0,9 - высокая; 0,9-1 - весьма высокая):

# %% [markdown]
# Теснота связи `target` с `period`, `multiple_lines` `total_charges` и `begin_date` - умеренная, с остальными признаками - слабая.
#
# Дополнительно отметим, что созданный дополнительно признак `money_per_day` имеет весьма высокую корреляцию с `internet_service`, а также "стриминговыми" признаками `streaming_movies` `streaming_tv`

# %% [markdown]
# Выводы по разделу:
#
# - объединили датасеты по общему признаку `customer_id`;
# - выделили в целевую переменную `target` признак `end_date`;
# - заполнили пропущенные на дату выгрузки датасета 1 февраля 2020 года значения  нулями в столбце `end_date`, т.к. клиенты ещё не успели накопить платежи;
# - создали два новых признака: `period` (общая длительность пользования клиентами сервисом, в днях) и `money_per_day` (прибыль от каждого клиента в день);
# - провели исследовательский анализ данных объединённой таблицы, составили приблизительный портрет клиента, покинувшего сервис: это человек допенсионного возраста, состоящий в браке, без детей. Использует оптоволоконную линию связи, контракт - с помесячной оплатой, счёт выставляется в электронном виде. Есть небольшой набор подключенных интернет-услуг и телефонии;
# - провели корреляционный анализ данных, установили, что теснота связей целевого признака `target` с `period`, `multiple_lines` `total_charges` и `begin_date` - умеренная, с остальными - слабая. Отметили, что признак `money_per_day` имеет весьма высокую корреляцию с `internet_service`, а также "стриминговыми" признаками `streaming_movies` `streaming_tv`.

# %% [markdown]
# ## Подготовка данных для обучения

# %% [markdown]
# Исключим из датасета признаки, не оказывающие влияние на целевой (корреляция, близкая к нулю), а также признаки, содержащие даты

# %%
data = data.drop(['tech_support', 'dependents', 'gender', \
                  'begin_date', 'end_date'], axis=1).copy()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   type               7043 non-null   object
#  1   paperless_billing  7043 non-null   object
#  2   payment_method     7043 non-null   object
#  3   monthly_charges    7043 non-null   float64
#  4   total_charges      7043 non-null   float64
#  5   senior_citizen     7043 non-null   object
#  6   partner            7043 non-null   object
#  7   internet_service   5517 non-null   object
#  8   online_security    5517 non-null   object
#  9   online_backup      5517 non-null   object
#  10  device_protection  5517 non-null   object
#  11  streaming_tv       5517 non-null   object
#  12  streaming_movies   5517 non-null   object
#  13  multiple_lines     6361 non-null   object
#  14  target             7043 non-null   int64
#  15  period             7043 non-null   int64
# ...

# %% [markdown]
# Самое время заполнить пропущенные значения в признаках:

# %%
columns_to_fill = [
    'internet_service',
    'online_security',
    'online_backup',
    'device_protection',
    'streaming_tv',
    'streaming_movies',
    'multiple_lines'
]

# перебираем каждый столбец
for column in columns_to_fill:
    data[column].fillna('No service', inplace=True)

# %% [markdown]
# Обнаруженные 11 пропусков в признаке `money_per_day` заполним медианным значением. Это не должно отразиться на данных, т.к. медиана менее подвержена влиянию выбросов

# %%
median_value = data['money_per_day'].median()
data['money_per_day'] = data['money_per_day'].fillna(median_value)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   type               7043 non-null   object
#  1   paperless_billing  7043 non-null   object
#  2   payment_method     7043 non-null   object
#  3   monthly_charges    7043 non-null   float64
#  4   total_charges      7043 non-null   float64
#  5   senior_citizen     7043 non-null   object
#  6   partner            7043 non-null   object
#  7   internet_service   7043 non-null   object
#  8   online_security    7043 non-null   object
#  9   online_backup      7043 non-null   object
#  10  device_protection  7043 non-null   object
#  11  streaming_tv       7043 non-null   object
#  12  streaming_movies   7043 non-null   object
#  13  multiple_lines     7043 non-null   object
#  14  target             7043 non-null   int64
#  15  period             7043 non-null   int64
# ...

# %% [markdown]
# Проверим, что пропуски отсутствуют

# %%
data.isna().sum()
# Out:
# type                 0
# paperless_billing    0
# payment_method       0
# monthly_charges      0
# total_charges        0
# senior_citizen       0
# partner              0
# internet_service     0
# online_security      0
# online_backup        0
# device_protection    0
# streaming_tv         0
# streaming_movies     0
# multiple_lines       0
# target               0
# period               0
# money_per_day        0
# dtype: int64

# %% [markdown]
# Проверим на дубликаты

# %%
data.duplicated().sum()
# Out:
# 15

# %%
# удалим образовавшиеся дубликаты
data = data.drop_duplicates().reset_index(drop = True)
data.duplicated().sum()
# Out:
# 0

# %%
# размер датасета перед сплитованием
data.shape[0]
# Out:
# 7028

# %%
# подготовим признаки и разделим на обучающую и тестовую выборки
X = data.drop('target', axis=1)
y = data['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, \
                                                  test_size=TEST_SIZE, \
                                                  stratify = data['target'], \
                                                  random_state=RANDOM_STATE)

print(f'Размер обучающей выборки: {X_train.shape}')
print(f'Размер тестовой выборки: {X_test.shape}')
# Out:
# Размер обучающей выборки: (5271, 16)
# Размер тестовой выборки: (1757, 16)

# %%
y_train.describe()
# Out:
# count    5271.000000
# mean        0.156707
# std         0.363558
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: target, dtype: float64

# %%
y_test.describe()
# Out:
# count    1757.000000
# mean        0.156517
# std         0.363448
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: target, dtype: float64

# %% [markdown]
# Размеры совпадают, деление на выборки и стратификация прошли успешно

# %%
data.head(10)
# Out:
#              type paperless_billing             payment_method  \
# 0  Month-to-month               Yes           Electronic check
# 1        One year                No               Mailed check
# 2  Month-to-month               Yes               Mailed check
# 3        One year                No  Bank transfer (automatic)
# 4  Month-to-month               Yes           Electronic check
# 5  Month-to-month               Yes           Electronic check
# 6  Month-to-month               Yes    Credit card (automatic)
# 7  Month-to-month                No               Mailed check
# 8  Month-to-month               Yes           Electronic check
# 9        One year                No  Bank transfer (automatic)
#
#    monthly_charges  total_charges senior_citizen partner internet_service  \
# 0            29.85          31.04              0     Yes              DSL
# 1            56.95        2071.84              0      No              DSL
# ...

# %%
num_cols = data.select_dtypes(include='number').columns.to_list()
num_cols.remove('target')

cat_cols = ['type', 'paperless_billing', 'payment_method', 'partner', \
            'internet_service', 'online_security', 'online_backup', \
            'device_protection', 'streaming_tv', 'streaming_movies', \
            'multiple_lines']

# %% [markdown]
# Для древесных и бустинговых моделей используем OrdinalEncoder вместо OneHotEncoder, чтобы не увеличивать количество признаков, в результате чего модели будет сложнее создавать разделяющие правила. Для нейронной сети, которая относится к линейным моделям, используем OneHotEncoder

# %%
col_transformer_ordinal = ColumnTransformer(transformers=[
                ('scaler', StandardScaler(), num_cols), \
                ('ordinal', OrdinalEncoder(handle_unknown='use_encoded_value', \
                                           unknown_value=-1), cat_cols)
                ],
                  remainder='drop',
                  n_jobs=-1
                  )

# %%
col_transformer_ohe = ColumnTransformer(transformers=[
                ('scaler', StandardScaler(), num_cols), \
                ('onehot', OneHotEncoder(sparse_output=False), cat_cols)
                ],
                  remainder='drop',
                  n_jobs=-1
                  )

# %%
X_train_ohe = col_transformer_ohe.fit_transform(X_train)
X_test_ohe = col_transformer_ohe.transform(X_test)

X_train_ordinal = col_transformer_ordinal.fit_transform(X_train)
X_test_ordinal = col_transformer_ordinal.transform(X_test)

# %% [markdown]
# Выводы по разделу:
#
# - исключили из датасета признаки, не оказывающие влияние на целевой (корреляция, близкая к нулю), а также признаки, содержащие даты;
# - заполнили пропущенные значения в бинарных признаках фразой "No service", а пропуски в `money_per_day` - медианой, удалили образовавшиеся дубликаты;
# - разделили датасет на тренировочную и тестовую выборки, кодировали количественные и категориальные признаки по-разному для линейной и нелинейных моделей, произвели трансформирование

# %% [markdown]
# ## Обучение моделей

# %% [markdown]
# Рассмотрим такие модели, как:
#
# - дерево решений
# - градиентные бустинги CatBoost и LightGBM
# - нейронная сеть

# %%
def model_param(model, parameters, features_train, target_train):

# инициализируем GridSearchCV для подбора гиперпараметров
    grid_cv = GridSearchCV(model,
                        param_grid = parameters,
                        cv=5,
                        n_jobs=-1,
                        scoring = 'roc_auc',
                           )

# делаем фиттинг модели на обучающих данных с подбором параметров
    grid_cv.fit(features_train, target_train)

# ищем лучшую модель
    best_model = grid_cv.best_estimator_

# используем лучший результат из GridSearchCV как оценку ROC-AUC
    roc_auc_best_model = round(grid_cv.best_score_, 2)

    # сохраняем статистику модели
    model_stat = roc_auc_best_model

    return model_stat

# %% [markdown]
# ### Модель DecisionTree

# %%
model_tree = DecisionTreeClassifier(random_state=RANDOM_STATE)

# %%
# гиперпараметры модели
param_grid_tree = {
    'max_depth': range(2, 5),
    'min_samples_split': range(2, 5),
    'min_samples_leaf': range(2, 5)
}

# %%
tree_stat = model_param(model_tree, param_grid_tree, \
                                      X_train_ordinal, y_train)

# %%
tree_stat
# Out:
# 0.77

# %% [markdown]
# ### Модель LightGBM

# %%
model_lgbm = LGBMClassifier(random_state=RANDOM_STATE)

# %%
model_lgbm.fit(X_train_ordinal, y_train)
# Out:
# LGBMClassifier(random_state=120525)

# %%
param_lgbm = {
    'num_leaves': range(2, 5),
    'max_depth': range(2, 5),
    'learning_rate': [0.01, 0.1, 0.2]
}

# %%
lgbm_stat = model_param(model_lgbm, param_lgbm, \
                                      X_train_ordinal, y_train)

# %%
lgbm_stat
# Out:
# 0.86

# %% [markdown]
# ### Модель CatBoost

# %%
model_catboost = CatBoostClassifier(random_state=RANDOM_STATE)

# %%
model_catboost.fit(X_train_ordinal, y_train)
# Out:
# Learning rate set to 0.02095
# 0:	learn: 0.6764157	total: 49.5ms	remaining: 49.5s
# 1:	learn: 0.6587656	total: 51.6ms	remaining: 25.8s
# 2:	learn: 0.6418536	total: 53.7ms	remaining: 17.9s
# 3:	learn: 0.6274452	total: 56.1ms	remaining: 14s
# 4:	learn: 0.6121591	total: 58.3ms	remaining: 11.6s
# 5:	learn: 0.5988947	total: 60.5ms	remaining: 10s
# 6:	learn: 0.5873611	total: 62.6ms	remaining: 8.88s
# 7:	learn: 0.5775355	total: 64.3ms	remaining: 7.97s
# 8:	learn: 0.5652545	total: 66.4ms	remaining: 7.32s
# 9:	learn: 0.5533240	total: 68.7ms	remaining: 6.8s
# 10:	learn: 0.5451344	total: 70.5ms	remaining: 6.33s
# 11:	learn: 0.5368851	total: 72.7ms	remaining: 5.99s
# 12:	learn: 0.5276851	total: 75ms	remaining: 5.69s
# 13:	learn: 0.5183647	total: 77.1ms	remaining: 5.43s
# 14:	learn: 0.5125027	total: 78.2ms	remaining: 5.13s
# 15:	learn: 0.5024921	total: 80.6ms	remaining: 4.96s
# 16:	learn: 0.4938599	total: 82.8ms	remaining: 4.79s
# 17:	learn: 0.4870715	total: 84.9ms	remaining: 4.63s
# ...

# %%
param_catboost = {
    'iterations': range(2, 5),
    'depth': range(2, 5),
    'learning_rate': [0.01, 0.1, 0.2]
}

# %%
catboost_stat = model_param(model_catboost, param_catboost, \
                                      X_train_ordinal, y_train)
# Out:
# 0:	learn: 0.6882864	total: 812us	remaining: 812us
# 1:	learn: 0.6835580	total: 1.61ms	remaining: 0us
# 0:	learn: 0.6882779	total: 739us	remaining: 739us
# 1:	learn: 0.6836748	total: 1.5ms	remaining: 0us
# 0:	learn: 0.6882743	total: 664us	remaining: 664us
# 1:	learn: 0.6836730	total: 1.41ms	remaining: 0us
# 0:	learn: 0.6882871	total: 654us	remaining: 654us
# 1:	learn: 0.6836846	total: 1.34ms	remaining: 0us
# 0:	learn: 0.6882737	total: 687us	remaining: 687us
# 1:	learn: 0.6836871	total: 1.51ms	remaining: 0us
# 0:	learn: 0.6466962	total: 717us	remaining: 717us
# 1:	learn: 0.6090465	total: 1.55ms	remaining: 0us
# 0:	learn: 0.6466701	total: 725us	remaining: 725us
# 1:	learn: 0.6090544	total: 1.4ms	remaining: 0us
# 0:	learn: 0.6466194	total: 659us	remaining: 659us
# 1:	learn: 0.6100680	total: 1.43ms	remaining: 0us
# 0:	learn: 0.6467755	total: 699us	remaining: 699us
# 1:	learn: 0.6101926	total: 1.37ms	remaining: 0us
# 0:	learn: 0.6466389	total: 656us	remaining: 656us
# ...

# %%
catboost_stat
# Out:
# 0.8

# %% [markdown]
# ### Модель нейронная сеть

# %%
X = np.array(X_train_ohe)
y = np.array(y_train)

# параметры k-fold
n_splits = 5  # количество фолдов
kf = KFold(n_splits=n_splits, shuffle=True, random_state=RANDOM_STATE)

# для хранения метрики ROC-AUC
auc_per_fold = []

# функция для создания модели
def create_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(units=200, activation=tf.nn.relu, \
                      kernel_initializer=tf.keras.initializers.GlorotNormal()),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(units=48, activation=tf.nn.relu, \
                      kernel_initializer=tf.keras.initializers.GlorotNormal()),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(units=1, activation='sigmoid', \
                      kernel_initializer=tf.keras.initializers.GlorotNormal())
    ])
    model.compile(loss='binary_crossentropy', optimizer='adam', \
                  metrics=[tf.keras.metrics.AUC(name='auc')])
    return model

# цикл по фолдам
fold_idx = 1
for train_idx, test_idx in kf.split(X):
    print(f"Обучение на фолде {fold_idx}/{n_splits}...")

    # разбиение на обучающие и тестовые данные
    X_train_fold, X_test_fold = X[train_idx], X[test_idx]
    y_train_fold, y_test_fold = y[train_idx], y[test_idx]

    # создаём модель
    model = create_model()

    # обучаем модель
    history = model.fit(X_train_fold, y_train_fold,
                        validation_data=(X_test_fold, y_test_fold),
                        epochs=10,
                        batch_size=32,
                        verbose=0)

    # оцениваем фолда
    predictions = (model.predict(X_test_fold) > 0.5).astype("int32")
    auc = roc_auc_score(y_test_fold, model.predict(X_test_fold))


    print(f"Фолд {fold_idx}: ROC-AUC = {auc:.4f}")

    # сохраняем метрику
    auc_per_fold.append(auc)

    fold_idx += 1

print("\nРезультаты кросс-валидации:")
print(f"Средняя ROC-AUC: {np.mean(auc_per_fold):.4f} ± \
                                                  {np.std(auc_per_fold):.4f}")
# Out:
# Обучение на фолде 1/5...
# 2025-05-15 19:57:41.163896: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Фолд 1: ROC-AUC = 0.8491
# Обучение на фолде 2/5...
# Фолд 2: ROC-AUC = 0.8249
# Обучение на фолде 3/5...
# Фолд 3: ROC-AUC = 0.8210
# Обучение на фолде 4/5...
# Фолд 4: ROC-AUC = 0.8414
# Обучение на фолде 5/5...
# Фолд 5: ROC-AUC = 0.8362
#
# Результаты кросс-валидации:
# Средняя ROC-AUC: 0.8345 ±                                                   0.0104

# %%
nn_stat = round((sum(auc_per_fold) / len(auc_per_fold)), 2)
nn_stat
# Out:
# 0.83

# %% [markdown]
# ### Сводная таблица

# %% [markdown]
# Соберём получившиеся метрики в сводную таблицу по моделям

# %%
results = {
    "Model": ["Decision Tree", "LightGBM", "CatBoost", "Neural Network"],
    "ROC-AUC": [
        tree_stat, lgbm_stat, catboost_stat, nn_stat
    ]
}

results_df = pd.DataFrame(results)

results_df
# Out:
#             Model  ROC-AUC
# 0   Decision Tree     0.77
# 1        LightGBM     0.86
# 2        CatBoost     0.80
# 3  Neural Network     0.83

# %% [markdown]
# Лучше остальных себя показала модель LightGBM, возьмём её для проверки на тестовой выборке

# %% [markdown]
# Выводы по разделу:
#
# - создали и обучили на тренировочных данных четыре модели: Дерева решений, градиентного бустинга LightGBM и CatBoost, а также нейронную сеть;
# - в качестве метрики для оценки лучшей модели была выбрана ROC-AUC, т.к. у нас задача бинарной классификации;
# - лучшей на тренировочных данных оказалась модель LightGBM, ROC-AUC = 0.86, взяли её для дальнейшего тестирования

# %% [markdown]
# ## Тестирование лучшей модели

# %% [markdown]
# ### Проверка качества лучшей модели

# %%
y_pred = model_lgbm.predict(X_test_ordinal)
y_pred_probs = model_lgbm.predict_proba(X_test_ordinal)[:, 1]

# %%
roc_auc = roc_auc_score(y_test, y_pred_probs)
print(f"ROC-AUC модели на тестовой выборке: {roc_auc:.2f}")
# Out:
# ROC-AUC модели на тестовой выборке: 0.88

# %% [markdown]
# На тесте модель LightGBM показала значение ROC-AUC, превышающее минимальное, согласно тех. заданию (>= 0.85)

# %% [markdown]
# Сравним результат с константной моделью DummyClassifier

# %%
# создаём константную модель
dummy_clf = DummyClassifier(strategy="most_frequent")
dummy_clf.fit(X_train_ordinal, y_train)

# предсказания константной модели и ROC-AUC
y_dummy_probs = dummy_clf.predict_proba(X_test_ordinal)[:, 1]
dummy_roc_auc = roc_auc_score(y_test, y_dummy_probs)
print(f"ROC-AUC константной модели: {dummy_roc_auc:.2f}")
# Out:
# ROC-AUC константной модели: 0.50

# %% [markdown]
# ### Расчёт Accuracy, построение матрицы ошибок и графика Precision-Recall

# %% [markdown]
# Посчитаем метрики Accuracy, Precision и Recall

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy = {accuracy:.2f}')
# Out:
# Accuracy = 0.88

# %%
recall = recall_score(y_test, y_pred)
print(f'Recall = {recall:.2f}')
# Out:
# Recall = 0.39

# %%
precision = precision_score(y_test, y_pred)
print(f'Precision = {precision:.2f}')
# Out:
# Precision = 0.76

# %% [markdown]
# Модель предоставляет высокую общую точность (Accuracy = 88%), но это не даёт полного представления о её полезности в работе с отказами клиентов. Высокий показатель связан с тем, что подавляющее большинство клиентов (скорее всего) остаются, и модель хорошо идентифицирует их.
# Низкий Recall (36%) означает, что модель пропускает значительное число клиентов, которые действительно склонны к отказу. В бизнес-смысле это может привести к упущению значительных возможностей для удержания и снижению эффективности использования модели.
# Высокий Precision (78%) указывает, что модель, хоть и пропускает многих уходящих клиентов, демонстрирует надежность в своей классификации. Если модель определяет клиента как склонного к отказу, бизнес может быть относительно уверен, что этот клиент действительно склонен уйти.
# Чтобы модель стала полезной для задачи предотвращения отказов, важно увеличить Recall, даже если это немного снизит Precision.

# %%
ConfusionMatrixDisplay.from_predictions (y_test, y_pred);

# %% [markdown]
# True Positive (1453) и True Negative (100) являются желаемыми результатами предсказаний модели. Они показывают, насколько точно модель справляется со своей задачей (клиент уйдёт или останется).
# False Positive (175) увеличивает затраты на удержание клиентов, так как модель направляет ресурсы на "ненужные" акции.
# False Negative (29) — это упущенные возможности и основной источник убытков, так как такие клиенты уходят, а компания не предпринимает мер для их удержания.

# %%
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_probs)

# %%
average_precision = average_precision_score(y_test, y_pred_probs)

# %%
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label=f'PR-кривая (AP = {average_precision:.2f})', \
         color='b')
plt.xlabel("Полнота (Recall)", fontsize=12)
plt.ylabel("Точность (Precision)", fontsize=12)
# добавим линию, представляющую базовый уровень случайной модели (точность 0.5)
plt.axhline(y=0.5, color='r', linestyle='--', \
            label='Baseline (случайная модель)')
plt.title("График Precision-Recall", fontsize=14)
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# При построении графика PR видно, как компромисс между точностью и полнотой зависит от выбранного порога классификации

# %% [markdown]
# ### Анализ важности признаков

# %%
feature_names = col_transformer_ordinal.get_feature_names_out()

# %%
X_train = pd.DataFrame(X_train_ordinal, columns=feature_names)
X_test = pd.DataFrame(X_test_ordinal, columns=feature_names)

# %%
explainer = shap.Explainer(model_lgbm, X_train)

# %%
shap_values = explainer(X_test, check_additivity=False)

# %%
shap.summary_plot(shap_values, X_test, show=False)

plt.xlabel('Распределение значений SHAP')
plt.ylabel('Признаки')
plt.title('Распределение важности признаков')
plt.show()

# %% [markdown]
# Наибольшую важность на целевой оказывают такие признаки, как:
#
# - `period` (общая длительность пользования клиентами сервисом, в днях)
# - `type` (тип оплаты: раз в год-два или ежемесячно)
# - `total_charges` (общие расходы клиента)
#
# Практически никак не влияют на то, покинет ли клиент сервис, различные интернет-услуги, предоставляемые сервисом

# %% [markdown]
# ### Дополнительное исследование для одного из признаков

# %% [markdown]
# Покажем график зависимости входного признака `period` и целевого

# %%
important_feature = X_train['scaler__period'].values

# %%
if important_feature.shape[0] != y_train.shape[0]:
    raise ValueError("Размеры important_feature и y_train должны совпадать")

# %%
# удалим строки с NaN, если такие есть
mask = ~np.isnan(important_feature) & ~np.isnan(y_train)
important_feature_clean = important_feature[mask]
y_train_clean = y_train[mask]

# %%
plt.figure(figsize=(8, 6))
plt.scatter(important_feature_clean, y_train_clean, alpha=0.6, \
            edgecolors='k', color='blue')
plt.xlabel('period')
plt.ylabel('Целевой признак')
plt.title('Зависимость period от целевого признака')
plt.grid(True)
plt.show()

# %%
len(important_feature_clean)
# Out:
# 5271

# %%
y_train_clean
# Out:
# 6589    0
# 4200    0
# 3462    0
# 2743    0
# 2264    0
#        ..
# 162     0
# 4754    0
# 5537    0
# 600     0
# 3359    0
# Name: target, Length: 5271, dtype: int64

# %% [markdown]
# Судя по графику, признаки `period` и `target` не так сильно зависимы друг от друга

# %% [markdown]
# Выводы по разделу:
#
# - проверили качество предсказаний модели LightGBM на тестовых данных, получили ROC-AUC = 0.89, что соответствует требованиям Заказчика (>= 0.85). Константная Dummy-модель показывает метрику, равную 0.5;
# - построили матрицу ошибок, предварительно вычислив Accuracy. Модель обладает высокой общей точностью (Accuracy = 88%). Низкий Recall (36%) означает, что модель пропускает значительное число клиентов, которые действительно склонны к уходу. Высокий Precision (78%) указывает, что модель, хоть и пропускает многих уходящих клиентов, демонстрирует надежность в своей классификации;
# - True Positive (1453) и True Negative (100) являются желаемыми результатами предсказаний модели. Они показывают, насколько точно модель справляется со своей задачей (клиент уйдёт или останется).
# False Positive (175) увеличивает затраты на удержание клиентов, так как модель направляет ресурсы на "ненужные" акции.
# False Negative (29) — это упущенные возможности и основной источник убытков, так как такие клиенты уходят, а компания не предпринимает мер для их удержания;
# - провели анализ важности входных признаков на целевой, ими стали (в порядке убывания): `period` (общая длительность пользования клиентами сервисом, в днях), `type` (тип оплаты: раз в год-два или ежемесячно), `total_charges` (общие расходы клиента). Практически никак не влияют на то, покинет ли клиент сервис, различные интернет-услуги, предоставляемые сервисом

# %% [markdown]
# ## Итоговый вывод

# %% [markdown]
# Перед нами стояла задача помочь Заказчику (компания «ТелеДом») построить модель, которая будет предсказывать, разорвёт ли абонент договор (спрогнозировать отток клиентов). Для этого мы обучили модель на данных, предоставленных Заказчиком, предварительно выполнив следующие этапы:
#
# - загрузка данных
# - предобработка и исследовательский анализ данных
# - объединение таблиц, анализ и создание новых признаков
# - подготовка данных для обучения и обучение моделей
# - тестирование лучшей модели, проверка её качества, построение матрицы ошибок и анализ важности признаков.
#
# С техническими деталями и подробными выводами можно ознакомиться в конце каждого раздела.
#
# Главное требование Заказчика было выполнено, лучшая модель на тесте показывает значение метрики ROC-AUC, равное 0.89.
#
# Рекомендации для бизнеса по уменьшению оттока клиентов, на основе проведённого исследования:
#
# *   Чем дольше время пользования сервисом, тем выше шансы, что клиенты останутся. Им следует рассылать спецпредложения и скидочные программы для удержания.
# *   Чем больше общие расходы клиента, тем выше шансы, что он уйдёт. Меньше вероятность отказаться от услуг сервиса у клиентов, заключивших контракт на 1-2 года, чем у тех, что оплачивают помесячно. Вероятно, стоит слегка уменьшить значение ежемесячного платежа для тех клиентов, которые ещё не заключили долгосрочный договор, но пользуются сервисом регулярно.
# *   Вариативность интернет-услуг и телефонии, типы платежей, социальный статус, возрастные и гендерные различия не оказывают влияния на отток клиентов - здесь бизнесу можно не придумывать ничего нового.
